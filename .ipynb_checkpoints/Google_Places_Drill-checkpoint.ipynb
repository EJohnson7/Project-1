# %%
# Dependencies
import requests
import json
import pandas as pd
import numpy as np
import csv
from pprint import pprint

# Google developer API key
from config import gkey

# %%
Zip_code = [33114, 33002, 33018, 33017, 33016, 33015, 33014, 33013, 33012, 33011, 33010, 33092, 
         33090, 33039, 33035, 33034, 33031, 33032, 33030, 33033, 33149, 33181, 33182, 33183, 
         33184, 33185, 33186, 33187, 33188, 33189, 33190, 33180, 33179, 33178, 33166, 33167, 
         33168, 33169, 33172, 33173, 33174, 33175, 33176, 33177, 33165, 33193, 33194, 33247, 
         33255, 33256, 33257, 33261, 33265, 33266, 33269, 33280, 33283, 33245, 33243, 33242, 
         33196, 33197, 33199, 33206, 33222, 33231, 33233, 33234, 33238, 33299, 33296, 33164, 
         33101, 33130, 33131, 33132, 33133, 33134, 33135, 33136, 33137, 33138, 33129, 33128, 
         33127, 33102, 33106, 33111, 33112, 33116, 33122, 33124, 33125, 33126, 33170, 33156, 
         33158, 33157, 33161, 33155, 33162, 33153, 33152, 33151, 33150, 33163, 33142, 33143, 
         33144, 33145, 33146, 33147, 33159, 33109, 33139, 33141, 33154, 33140, 33119, 33239, 
         33056, 33160, 33055, 33054]

# %%
# set up lists to hold reponse info
lati = []
long = []

# %%
# 1. What are the geocoordinates (latitude and longitude) of Zip Codes

target_zip = "33131"

params = {"address": target_zip, "key": gkey}

# Build URL using the Google Maps API
base_url = "https://maps.googleapis.com/maps/api/geocode/json"

print(f"Drill #1: The Geocoordinates of zip code {target_zip}")

# Run request
response = requests.get(base_url, params=params)

# Convert to JSON
zip_geo = response.json()

# Extract lat/lng
lat = zip_geo["results"][0]["geometry"]["location"]["lat"]
lng = zip_geo["results"][0]["geometry"]["location"]["lng"]

# Print results
print(f"{target_zip}: {lat}, {lng}")
# Out:
# Drill #1: The Geocoordinates of zip code 33131
# 33131: 25.76528, -80.1847167

# %%
# Loop through the list of cities and perform a request for data on each
for zipcodes in Zip_code[:10]:
    target_zip = zipcodes
    params = {"address": str(target_zip), "key": gkey}
    response = requests.get(base_url, params=params)
    zip_geo = response.json()
    lati.append(zip_geo["results"][0]["geometry"]["location"]["lat"])
    long.append(zip_geo["results"][0]["geometry"]["location"]["lng"])

# %%
lati
# Out:
# [25.7897333,
#  25.8665814,
#  25.9231399,
#  25.9410503,
#  25.8925211,
#  25.9358702,
#  25.9109586,
#  25.8618743,
#  25.8641207,
#  25.824762]

# %%
# create a data frame from cities, lat, and temp
zipcode_dict = {
    "zip": Zip_code[:10],
    "latit": lati,
    "longi": long
}
zipcode_data = pd.DataFrame(zipcode_dict)
zipcode_data.dtypes
#zipcode_data
# Out:
# zip        int64
# latit    float64
# longi    float64
# dtype: object

# %%
# Need to zip lat and longi
zip_coords = zip(zipcode_data["latit"], zipcode_data["longi"])
print(zip_coords)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-141-6aeab0d7b738> in <module>
#       2 zip_lat = zipcode_data["latit"]
#       3 zip_lon = zipcode_data["longi"]
# ----> 4 zip_coords = zip(zipcode_data["latit"], zipcode_data["longi"])
#       5 print(zip_coords)
#
# TypeError: 'int' object is not callable

# %%
# 3. Find the name and address of a gym in the zips. Needs to be gym as it is the type name provided by google
#    Hint: See https://developers.google.com/places/web-service/supported_types

target_type = "gym"
zip_coords = "25.76528,-80.1847167"
radius = 2000

# rewrite params dict

params2 = {
    "location": zip_coords,
    "types": target_type,
    "radius": radius,
    "key": gkey
}

# Build URL using the Google Maps API
base_url2 = "https://maps.googleapis.com/maps/api/place/nearbysearch/json"

print("Fitness Center near ZIP")

# Run request
response = requests.get(base_url2, params2)

gym_zip = response.json()

# Print the JSON (pretty printed)
pprint(json.dumps(gym_zip, indent=4, sort_keys=True))
# Out:
# Fitness Center near ZIP
# ('{\n'
#  '    "html_attributions": [],\n'
#  '    "next_page_token": '
#  '"CqQCGQEAAKjXdcrH1leAjlw6T8R2y15lHW8Kan-_xOQXeCvKO2pShMpxNVbAAZpQ1CHK4AJEIxOnMFKChbMfWqVh1ocgIIeWmwjgvsx6iAXqK0P4haOuPYX2Q8JcW80I15LhXrg1_D4ZSTD-GzFe_Uu9r30h3AckSHZaeIgMo1R9V8SZNftlR83j-r_gPdvrxUMNozlwmJM_ly4vQeoIQrbkitMhsnmf_N92UT3eelhMlKy2yIwVAs_sPpO67wQpXAcGH4qMq6GVhOHEbVNfrLbytUkuxHjART5quyEcnSO2gagzEv4cYBkQLdQJI08u60GCxpU6NMqrqj78Zd-zxr6q4AfQRRKjT6g_FKEOsqiO7bkw6Z_YLEvO73wWffsxgEyCPoseWxIQv0_ULRFJNOVfeth25ck8kxoULkohqhxrhqsJfAHAB0mzuUsj93E",\n'
#  '    "results": [\n'
#  '        {\n'
#  '            "geometry": {\n'
#  '                "location": {\n'
#  '                    "lat": 25.7705359,\n'
#  '                    "lng": -80.1896106\n'
#  '                },\n'
#  '                "viewport": {\n'
#  '                    "northeast": {\n'
#  '                        "lat": 25.7720798802915,\n'
#  '                        "lng": -80.1882674197085\n'
#  '                    },\n'
#  '                    "southwest": {\n'
#  '                        "lat": 25.7693819197085,\n'
#  '                        "lng": -80.1909653802915\n'
#  '                    }\n'
#  '                }\n'
#  '            },\n'
#  '            "icon": '
#  '"https://maps.gstatic.com/mapfiles/place_api/icons/generic_business-71.png",\n'
#  '            "id": "96cb01756891163b1ae294fd098ed384a8e49991",\n'
#  '            "name": "Exhale Downtown Miami",\n'
#  '            "opening_hours": {\n'
#  '                "open_now": true\n'
#  '            },\n'
#  '            "photos": [\n'
#  '                {\n'
#  '                    "height": 501,\n'
#  '                    "html_attributions": [\n'
#  '                        "<a '
#  'href=\\"https://maps.google.com/maps/contrib/105796525682208844069/photos\\">Exhale '
#  'Downtown Miami</a>"\n'
#  '                    ],\n'
#  '                    "photo_reference": '
#  '"CmRaAAAAbEbmZtwv6187z9_FWq7qE1oVDBF9MOfu73luttw_w9yqdivgbgwjCGdff35ywejwYybS_sN6SRW4pids53BM8ME--8S2C6_JOo1wUTPLtqi250LizZd-gOBFymbPueL7EhAS4qErxQjynitil8wdQfJeGhSNUJ761-jUkHVVFFRXM1c-iUqULA",\n'
#  '                    "width": 725\n'
#  '                }\n'
#  '            ],\n'
#  '            "place_id": "ChIJlWF1Gp222YgRB9JmxCuG8Nc",\n'
#  '            "plus_code": {\n'
#  '                "compound_code": "QRC6+65 Miami, Florida, United States",\n'
#  '                "global_code": "76QXQRC6+65"\n'
#  '            },\n'
#  '            "rating": 3.8,\n'
#  '            "reference": "ChIJlWF1Gp222YgRB9JmxCuG8Nc",\n'
#  '            "scope": "GOOGLE",\n'
#  '            "types": [\n'
#  '                "spa",\n'
#  '                "beauty_salon",\n'
#  '                "gym",\n'
#  '                "health",\n'
#  '                "point_of_interest",\n'
#  '                "establishment"\n'
#  '            ],\n'
#  '            "user_ratings_total": 21,\n'
#  '            "vicinity": "270 Biscayne Boulevard Way #16, Miami"\n'
#  '        },\n'
#  '        {\n'
#  '            "geometry": {\n'
#  '                "location": {\n'
#  '                    "lat": 25.7649411,\n'
#  '                    "lng": -80.1943902\n'
#  '                },\n'
#  '                "viewport": {\n'
#  '                    "northeast": {\n'
#  '                        "lat": 25.7661028302915,\n'
#  '                        "lng": -80.1930531197085\n'
#  '                    },\n'
#  '                    "southwest": {\n'
#  '                        "lat": 25.7634048697085,\n'
#  '                        "lng": -80.1957510802915\n'
#  '                    }\n'
#  '                }\n'
#  '            },\n'
#  '            "icon": '
#  '"https://maps.gstatic.com/mapfiles/place_api/icons/generic_business-71.png",\n'
#  '            "id": "385c0e3fd22e344f3e108f70d8f291b53f66da15",\n'
#  '            "name": "LA Fitness",\n'
#  '            "opening_hours": {\n'
#  '                "open_now": true\n'
#  '            },\n'
#  '            "photos": [\n'
#  '                {\n'
#  '                    "height": 3000,\n'
#  '                    "html_attributions": [\n'
#  '                        "<a '
#  'href=\\"https://maps.google.com/maps/contrib/107922111300703851466/photos\\">Rhonic '
#  'Lopez</a>"\n'
#  '                    ],\n'
#  '                    "photo_reference": '
#  '"CmRaAAAAF69YROBJvojRgxDK6b0IVMHfUoFAMwNYlMLz3sQEijWMoQhNpVWfIyAkUKHkBu2WuUrGgi7cneB2ERCbD9KlNLHW6CuuZEP0DuBXp0amqxloJ1FS6PjDpiWF-VetQFESEhB4TRTrLGZK7HXUKOdEJZvjGhR-MAFLG00cWgYtexKJsiwwBExjsQ",\n'
#  '                    "width": 4000\n'
#  '                }\n'
#  '            ],\n'
#  '            "place_id": "ChIJ6z3keYS22YgR40tT58c-BWQ",\n'
#  '            "plus_code": {\n'
#  '                "compound_code": "QR74+X6 Miami, Florida, United States",\n'
#  '                "global_code": "76QXQR74+X6"\n'
#  '            },\n'
#  '            "rating": 2.7,\n'
#  '            "reference": "ChIJ6z3keYS22YgR40tT58c-BWQ",\n'
#  '            "scope": "GOOGLE",\n'
#  '            "types": [\n'
#  '                "gym",\n'
#  '                "spa",\n'
#  '                "health",\n'
#  '                "point_of_interest",\n'
#  '                "establishment"\n'
#  '            ],\n'
#  '            "user_ratings_total": 239,\n'
#  '            "vicinity": "900 South Miami Avenue #236, Miami"\n'
#  '        },\n'
#  '        {\n'
#  '            "geometry": {\n'
#  '                "location": {\n'
#  '                    "lat": 25.7659418,\n'
#  '                    "lng": -80.1949659\n'
#  '                },\n'
#  '                "viewport": {\n'
#  '                    "northeast": {\n'
#  '                        "lat": 25.76728983029151,\n'
#  '                        "lng": -80.1937726197085\n'
#  '                    },\n'
#  '                    "southwest": {\n'
#  '                        "lat": 25.7645918697085,\n'
#  '                        "lng": -80.19647058029152\n'
#  '                    }\n'
#  '                }\n'
#  '            },\n'
#  '            "icon": '
#  '"https://maps.gstatic.com/mapfiles/place_api/icons/school-71.png",\n'
#  '            "id": "eed5f63cce9c06b2137e9446a835c4449a595ad8",\n'
#  '            "name": "Hot Yoga Brickell (Nacho Cano)",\n'
#  '            "opening_hours": {\n'
#  '                "open_now": true\n'
#  '            },\n'
#  '            "place_id": "ChIJ4xsi9IS22YgRtWTH4MnbF0M",\n'
#  '            "plus_code": {\n'
#  '                "compound_code": "QR84+92 Miami, Florida, United States",\n'
#  '                "global_code": "76QXQR84+92"\n'
#  '            },\n'
#  '            "rating": 4.5,\n'
#  '            "reference": "ChIJ4xsi9IS22YgRtWTH4MnbF0M",\n'
#  '            "scope": "GOOGLE",\n'
#  '            "types": [\n'
#  '                "gym",\n'
#  '                "health",\n'
#  '                "point_of_interest",\n'
#  '                "establishment"\n'
#  '            ],\n'
#  '            "user_ratings_total": 28,\n'
#  '            "vicinity": "809 Southwest 1st Avenue, Miami"\n'
#  '        },\n'
#  '        {\n'
#  '            "geometry": {\n'
#  '                "location": {\n'
#  '                    "lat": 25.75988,\n'
#  '                    "lng": -80.2002017\n'
#  '                },\n'
#  '                "viewport": {\n'
#  '                    "northeast": {\n'
#  '                        "lat": 25.7615117302915,\n'
#  '                        "lng": -80.1990969197085\n'
#  '                    },\n'
#  '                    "southwest": {\n'
#  '                        "lat": 25.7588137697085,\n'
#  '                        "lng": -80.2017948802915\n'
#  '                    }\n'
#  '                }\n'
#  '            },\n'
#  '            "icon": '
#  '"https://maps.gstatic.com/mapfiles/place_api/icons/school-71.png",\n'
#  '            "id": "f314663b5e7880e093cc4d134803fb4e5bb29fce",\n'
#  '            "name": "Sanctuary Seven Pilates",\n'
#  '            "opening_hours": {\n'
#  '                "open_now": true\n'
#  '            },\n'
#  '            "place_id": "ChIJZeeJ7Yi22YgRP9_4vsTovSo",\n'
#  '            "plus_code": {\n'
#  '                "compound_code": "QQ5X+XW Miami, Florida, United States",\n'
#  '                "global_code": "76QXQQ5X+XW"\n'
#  '            },\n'
#  '            "rating": 3.9,\n'
#  '            "reference": "ChIJZeeJ7Yi22YgRP9_4vsTovSo",\n'
#  '            "scope": "GOOGLE",\n'
#  '            "types": [\n'
#  '                "gym",\n'
#  '                "health",\n'
#  '                "point_of_interest",\n'
#  '                "school",\n'
#  '                "establishment"\n'
#  '            ],\n'
#  '            "user_ratings_total": 13,\n'
#  '            "vicinity": "1797 Southwest 3rd Avenue, Miami"\n'
#  '        },\n'
#  '        {\n'
#  '            "geometry": {\n'
#  '                "location": {\n'
#  '                    "lat": 25.758913,\n'
#  '                    "lng": -80.19215899999999\n'
#  '                },\n'
#  '                "viewport": {\n'
#  '                    "northeast": {\n'
#  '                        "lat": 25.7602940302915,\n'
#  '                        "lng": -80.19097061970848\n'
#  '                    },\n'
#  '                    "southwest": {\n'
#  '                        "lat": 25.75759606970849,\n'
#  '                        "lng": -80.19366858029149\n'
#  '                    }\n'
#  '                }\n'
#  '            },\n'
#  '            "icon": '
#  '"https://maps.gstatic.com/mapfiles/place_api/icons/generic_business-71.png",\n'
#  '            "id": "d1468056af6ad029db083782db00733dead14d6d",\n'
#  '            "name": "Equinox Brickell",\n'
#  '            "opening_hours": {\n'
#  '                "open_now": true\n'
#  '            },\n'
#  '            "photos": [\n'
#  '                {\n'
#  '                    "height": 1920,\n'
#  '                    "html_attributions": [\n'
#  '                        "<a '
#  'href=\\"https://maps.google.com/maps/contrib/104936279344430577827/photos\\">Jay '
#  'B</a>"\n'
#  '                    ],\n'
#  '                    "photo_reference": '
#  '"CmRaAAAA9GMcoJM7r2wETRWVektFJBQhvF38TVZLYWKUjZwPmiKQODTzYrtR973NA-rFPexx7a-P6mS70QlOtZhlsDVXXczMtnUNXQdzk8yMjBMiCuENrEQED6580N5nMHtqy3z6EhBoulubQlmSYQRimLK6d_LYGhR630i8LYPQ3tNGnZLDaKnAwZHS8g",\n'
#  '                    "width": 2560\n'
#  '                }\n'
#  '            ],\n'
#  '            "place_id": "ChIJKany2oC22YgRr_-hym9EriM",\n'
#  '            "plus_code": {\n'
#  '                "compound_code": "QR55+H4 Miami, Florida, United States",\n'
#  '                "global_code": "76QXQR55+H4"\n'
#  '            },\n'
#  '            "rating": 3.6,\n'
#  '            "reference": "ChIJKany2oC22YgRr_-hym9EriM",\n'
#  '            "scope": "GOOGLE",\n'
#  '            "types": [\n'
#  '                "gym",\n'
#  '                "spa",\n'
#  '                "health",\n'
#  '                "point_of_interest",\n'
#  '                "establishment"\n'
#  '            ],\n'
#  '            "user_ratings_total": 41,\n'
#  '            "vicinity": "1441 Brickell Avenue #4, Miami"\n'
#  '        },\n'
#  '        {\n'
#  '            "geometry": {\n'
#  '                "location": {\n'
#  '                    "lat": 25.7580426,\n'
#  '                    "lng": -80.1991177\n'
#  '                },\n'
#  '                "viewport": {\n'
#  '                    "northeast": {\n'
#  '                        "lat": 25.75934103029151,\n'
#  '                        "lng": -80.19772446970849\n'
#  '                    },\n'
#  '                    "southwest": {\n'
#  '                        "lat": 25.7566430697085,\n'
#  '                        "lng": -80.20042243029151\n'
#  '                    }\n'
#  '                }\n'
#  '            },\n'
#  '            "icon": '
#  '"https://maps.gstatic.com/mapfiles/place_api/icons/school-71.png",\n'
#  '            "id": "bda404b29f87bf182a18a220a5711ceccebf0b3d",\n'
#  '            "name": "Skanda Yoga Studio",\n'
#  '            "opening_hours": {\n'
#  '                "open_now": true\n'
#  '            },\n'
#  '            "photos": [\n'
#  '                {\n'
#  '                    "height": 576,\n'
#  '                    "html_attributions": [\n'
#  '                        "<a '
#  'href=\\"https://maps.google.com/maps/contrib/113458406076430876267/photos\\">Skanda '
#  'Yoga Studio Miami</a>"\n'
#  '                    ],\n'
#  '                    "photo_reference": '
#  '"CmRaAAAAj947kWEQ5rCW811PFTSExtp27lM-28E4zJp8mfLFfSKOL3KZHIcy_sStcE8KV1E26IgsJtMyVuAHeXXH3J8EzrUu_EZczgWIaINOeJoiJxkdIXflzOAGZJ1bRzieXSBMEhDUjNqmpIe6uAl47CEHrj8aGhTz83OJa7Cu-FgnFBgbzxJXLz3SIA",\n'
#  '                    "width": 1024\n'
#  '                }\n'
#  '            ],\n'
#  '            "place_id": "ChIJHbaiBIi22YgRi9ehwr04XYY",\n'
#  '            "plus_code": {\n'
#  '                "compound_code": "QR52+69 Miami, Florida, United States",\n'
#  '                "global_code": "76QXQR52+69"\n'
#  '            },\n'
#  '            "rating": 4.6,\n'
#  '            "reference": "ChIJHbaiBIi22YgRi9ehwr04XYY",\n'
#  '            "scope": "GOOGLE",\n'
#  '            "types": [\n'
#  '                "gym",\n'
#  '                "health",\n'
#  '                "point_of_interest",\n'
#  '                "establishment"\n'
#  '            ],\n'
#  '            "user_ratings_total": 32,\n'
#  '            "vicinity": "1800 Southwest 1st Avenue #102, Miami"\n'
#  '        },\n'
#  '        {\n'
#  '            "geometry": {\n'
#  '                "location": {\n'
#  '                    "lat": 25.7582027,\n'
#  '                    "lng": -80.1988872\n'
#  '                },\n'
#  '                "viewport": {\n'
#  '                    "northeast": {\n'
#  '                        "lat": 25.7595022802915,\n'
#  '                        "lng": -80.19749496970849\n'
#  '                    },\n'
#  '                    "southwest": {\n'
#  '                        "lat": 25.75680431970849,\n'
#  '                        "lng": -80.20019293029151\n'
#  '                    }\n'
#  '                }\n'
#  '            },\n'
#  '            "icon": '
#  '"https://maps.gstatic.com/mapfiles/place_api/icons/generic_business-71.png",\n'
#  '            "id": "06b2094cfce9e404a6403d97e3459cd65724b598",\n'
#  '            "name": "Cure Fitness",\n'
#  '            "photos": [\n'
#  '                {\n'
#  '                    "height": 1836,\n'
#  '                    "html_attributions": [\n'
#  '                        "<a '
#  'href=\\"https://maps.google.com/maps/contrib/110012544942192146075/photos\\">Roberto '
#  'Velez</a>"\n'
#  '                    ],\n'
#  '                    "photo_reference": '
#  '"CmRaAAAATvBx54iOKQfgS2TM7LmLgh4H01VBQ2-bw9CcFkL5SKVrNL4q4EnVToq8mPI_rsn2geaDxqzlos6Tz-U8X1dCwcl_TFskyorFXiIbDKy-4JEQxaY4czZxUUz8attijzo7EhCx6cnC06MPT0AAdNXgc6BwGhTVgR-gK4Uz5UBRGwO9aJums1xEJA",\n'
#  '                    "width": 3264\n'
#  '                }\n'
#  '            ],\n'
#  '            "place_id": "ChIJHbaiBIi22YgRNUay8xqGlCY",\n'
#  '            "plus_code": {\n'
#  '                "compound_code": "QR52+7C Miami, Florida, United States",\n'
#  '                "global_code": "76QXQR52+7C"\n'
#  '            },\n'
#  '            "rating": 4.4,\n'
#  '            "reference": "ChIJHbaiBIi22YgRNUay8xqGlCY",\n'
#  '            "scope": "GOOGLE",\n'
#  '            "types": [\n'
#  '                "gym",\n'
#  '                "health",\n'
#  '                "point_of_interest",\n'
#  '                "establishment"\n'
#  '            ],\n'
#  '            "user_ratings_total": 7,\n'
#  '            "vicinity": "1800 Southwest 1st Avenue, Miami"\n'
#  '        },\n'
#  '        {\n'
#  '            "geometry": {\n'
#  '                "location": {\n'
#  '                    "lat": 25.760526,\n'
#  '                    "lng": -80.2005449\n'
#  '                },\n'
#  '                "viewport": {\n'
#  '                    "northeast": {\n'
#  '                        "lat": 25.7618631802915,\n'
#  '                        "lng": -80.19918576970849\n'
#  '                    },\n'
#  '                    "southwest": {\n'
#  '                        "lat": 25.7591652197085,\n'
#  '                        "lng": -80.2018837302915\n'
#  '                    }\n'
#  '                }\n'
#  '            },\n'
#  '            "icon": '
#  '"https://maps.gstatic.com/mapfiles/place_api/icons/generic_business-71.png",\n'
#  '            "id": "bc73f2c335a88921d33cd9ffeb5d12edafd1fa68",\n'
#  '            "name": "Dubail Fitness Institute",\n'
#  '            "opening_hours": {\n'
#  '                "open_now": true\n'
#  '            },\n'
#  '            "photos": [\n'
#  '                {\n'
#  '                    "height": 1836,\n'
#  '                    "html_attributions": [\n'
#  '                        "<a '
#  'href=\\"https://maps.google.com/maps/contrib/105104619176368689211/photos\\">Cindy '
#  'Hing</a>"\n'
#  '                    ],\n'
#  '                    "photo_reference": '
#  '"CmRaAAAAvCGof_jIXyXX9AJ7uJRMCy1ixUlz5lDtYZI_x0OWJR3uhdtP6pFnj67ZY_uAmu8d8NZuRT4Fl4pDxiL33XGXbGCx8UMoA24ICMQf-iZUuvGWv6QTOXWIby0EH2me6bbMEhBSNoxrzjyo3UNVsw6QqWONGhQgRZV-Hp7qgrzjEHDf45-elk6UMg",\n'
#  '                    "width": 3264\n'
#  '                }\n'
#  '            ],\n'
#  '            "place_id": "ChIJfQA89oi22YgRECtGQXd7SXc",\n'
#  '            "plus_code": {\n'
#  '                "compound_code": "QQ6X+6Q Miami, Florida, United States",\n'
#  '                "global_code": "76QXQQ6X+6Q"\n'
#  '            },\n'
#  '            "rating": 5,\n'
#  '            "reference": "ChIJfQA89oi22YgRECtGQXd7SXc",\n'
#  '            "scope": "GOOGLE",\n'
#  '            "types": [\n'
#  '                "gym",\n'
#  '                "health",\n'
#  '                "point_of_interest",\n'
#  '                "establishment"\n'
#  '            ],\n'
#  '            "user_ratings_total": 13,\n'
#  '            "vicinity": "1785 Southwest 3rd Avenue, Miami"\n'
#  '        },\n'
#  '        {\n'
#  '            "geometry": {\n'
#  '                "location": {\n'
#  '                    "lat": 25.772552,\n'
#  '                    "lng": -80.201335\n'
#  '                },\n'
#  '                "viewport": {\n'
#  '                    "northeast": {\n'
#  '                        "lat": 25.7739309302915,\n'
#  '                        "lng": -80.1998693197085\n'
#  '                    },\n'
#  '                    "southwest": {\n'
#  '                        "lat": 25.7712329697085,\n'
#  '                        "lng": -80.2025672802915\n'
#  '                    }\n'
#  '                }\n'
#  '            },\n'
#  '            "icon": '
#  '"https://maps.gstatic.com/mapfiles/place_api/icons/school-71.png",\n'
#  '            "id": "162f683e1d0e0af088504d58204b4e995840f79c",\n'
#  '            "name": "Dharmi Yoga",\n'
#  '            "opening_hours": {\n'
#  '                "open_now": true\n'
#  '            },\n'
#  '            "photos": [\n'
#  '                {\n'
#  '                    "height": 650,\n'
#  '                    "html_attributions": [\n'
#  '                        "<a '
#  'href=\\"https://maps.google.com/maps/contrib/109246784951037751020/photos\\">Dharmi '
#  'Yoga</a>"\n'
#  '                    ],\n'
#  '                    "photo_reference": '
#  '"CmRaAAAA4dCD7v-AStEejPB-QVm0JvY36IEBYLedeEt8S_1sDqLu-c7eh9cFwkVSRu6bhWYLCphuHirac1cBo4J318aUBuv_WhHnXNQthg2J9FvZq6_Q3p8fOm1fvnUqWsfMMKEpEhA6PDwxF4thZ82ajEdRqs_tGhSKMdMpDKiv_SjDase_JFXrOVzUuQ",\n'
#  '                    "width": 1170\n'
#  '                }\n'
#  '            ],\n'
#  '            "place_id": "ChIJz7n5Ff6z2YgRgWFB2gnpXLM",\n'
#  '            "plus_code": {\n'
#  '                "compound_code": "QQFX+2F Miami, Florida, United States",\n'
#  '                "global_code": "76QXQQFX+2F"\n'
#  '            },\n'
#  '            "rating": 5,\n'
#  '            "reference": "ChIJz7n5Ff6z2YgRgWFB2gnpXLM",\n'
#  '            "scope": "GOOGLE",\n'
#  '            "types": [\n'
#  '                "gym",\n'
#  '                "health",\n'
#  '                "point_of_interest",\n'
#  '                "establishment"\n'
#  '            ],\n'
#  '            "user_ratings_total": 1,\n'
#  '            "vicinity": "118 Southwest South River Drive, Miami"\n'
#  '        },\n'
#  '        {\n'
#  '            "geometry": {\n'
#  '                "location": {\n'
#  '                    "lat": 25.7744138,\n'
#  '                    "lng": -80.19042739999999\n'
#  '                },\n'
#  '                "viewport": {\n'
#  '                    "northeast": {\n'
#  '                        "lat": 25.7756836802915,\n'
#  '                        "lng": -80.1890753197085\n'
#  '                    },\n'
#  '                    "southwest": {\n'
#  '                        "lat": 25.7729857197085,\n'
#  '                        "lng": -80.19177328029151\n'
#  '                    }\n'
#  '                }\n'
#  '            },\n'
#  '            "icon": '
#  '"https://maps.gstatic.com/mapfiles/place_api/icons/generic_business-71.png",\n'
#  '            "id": "b812e3d4401774ae92419049ac27273b9facad03",\n'
#  '            "name": "Getting Fit Miami",\n'
#  '            "opening_hours": {\n'
#  '                "open_now": true\n'
#  '            },\n'
#  '            "photos": [\n'
#  '                {\n'
#  '                    "height": 667,\n'
#  '                    "html_attributions": [\n'
#  '                        "<a '
#  'href=\\"https://maps.google.com/maps/contrib/101834794330290312503/photos\\">Getting '
#  'Fit Miami</a>"\n'
#  '                    ],\n'
#  '                    "photo_reference": '
#  '"CmRaAAAAkQGBxEy0IFCVYC_b3S6VIUdaaF_vcZTFFyrwQ-wzLUQphYjgw_5pieW3SeyJslcZYhFsHjMPaXJy4TFc-UL8nx9WoTb3IRU6OgD8t3GXU8W-GCLHf_Lp1jdVPi5vEkYCEhCeFHeii_7R6_3x3PDurvrbGhRrervHHS9uk9Me54OvKPBfRLhReg",\n'
#  '                    "width": 500\n'
#  '                }\n'
#  '            ],\n'
#  '            "place_id": "ChIJlY4mKpy22YgR4ogdg6shtUE",\n'
#  '            "plus_code": {\n'
#  '                "compound_code": "QRF5+QR Miami, Florida, United States",\n'
#  '                "global_code": "76QXQRF5+QR"\n'
#  '            },\n'
#  '            "reference": "ChIJlY4mKpy22YgR4ogdg6shtUE",\n'
#  '            "scope": "GOOGLE",\n'
#  '            "types": [\n'
#  '                "gym",\n'
#  '                "health",\n'
#  '                "point_of_interest",\n'
#  '                "establishment"\n'
#  '            ],\n'
#  '            "vicinity": "199 East Flagler Street, Miami"\n'
#  '        },\n'
#  '        {\n'
#  '            "geometry": {\n'
#  '                "location": {\n'
#  '                    "lat": 25.77699,\n'
#  '                    "lng": -80.18879799999999\n'
#  '                },\n'
#  '                "viewport": {\n'
#  '                    "northeast": {\n'
#  '                        "lat": 25.7784101302915,\n'
#  '                        "lng": -80.18718021970848\n'
#  '                    },\n'
#  '                    "southwest": {\n'
#  '                        "lat": 25.7757121697085,\n'
#  '                        "lng": -80.1898781802915\n'
#  '                    }\n'
#  '                }\n'
#  '            },\n'
#  '            "icon": '
#  '"https://maps.gstatic.com/mapfiles/place_api/icons/generic_business-71.png",\n'
#  '            "id": "f57b5b6ee8110074cb9d2e7065d8e1768fbf5556",\n'
#  '            "name": "Orangetheory Fitness",\n'
#  '            "opening_hours": {\n'
#  '                "open_now": true\n'
#  '            },\n'
#  '            "photos": [\n'
#  '                {\n'
#  '                    "height": 3096,\n'
#  '                    "html_attributions": [\n'
#  '                        "<a '
#  'href=\\"https://maps.google.com/maps/contrib/114539701154701973658/photos\\">Joe '
#  'HARB</a>"\n'
#  '                    ],\n'
#  '                    "photo_reference": '
#  '"CmRaAAAA-rmZwi4-VNbJlkmv8xR-DGk8ch7DiOnKfbCFEG13N4xkqm1Xz487j0v8eNsDdPi3Dd5ThSS5W9ofE_SmXYSMztmUgNsf37FasrkWjv1Z4mabn7owxODQVzYHS6QcgWZzEhDZarB5JGqXqe3gfVF9QoryGhRxT4P4mOjqLqZsH4bV8jRNccCgyQ",\n'
#  '                    "width": 4128\n'
#  '                }\n'
#  '            ],\n'
#  '            "place_id": "ChIJtabGO5622YgRtGwQ8Drj7vc",\n'
#  '            "plus_code": {\n'
#  '                "compound_code": "QRG6+QF Miami, Florida, United States",\n'
#  '                "global_code": "76QXQRG6+QF"\n'
#  '            },\n'
#  '            "rating": 3.9,\n'
#  '            "reference": "ChIJtabGO5622YgRtGwQ8Drj7vc",\n'
#  '            "scope": "GOOGLE",\n'
#  '            "types": [\n'
#  '                "gym",\n'
#  '                "health",\n'
#  '                "point_of_interest",\n'
#  '                "establishment"\n'
#  '            ],\n'
#  '            "user_ratings_total": 54,\n'
#  '            "vicinity": "244 Biscayne Boulevard, Miami"\n'
#  '        },\n'
#  '        {\n'
#  '            "geometry": {\n'
#  '                "location": {\n'
#  '                    "lat": 25.7652735,\n'
#  '                    "lng": -80.19030479999999\n'
#  '                },\n'
#  '                "viewport": {\n'
#  '                    "northeast": {\n'
#  '                        "lat": 25.7665567302915,\n'
#  '                        "lng": -80.18864846970848\n'
#  '                    },\n'
#  '                    "southwest": {\n'
#  '                        "lat": 25.7638587697085,\n'
#  '                        "lng": -80.19134643029149\n'
#  '                    }\n'
#  '                }\n'
#  '            },\n'
#  '            "icon": '
#  '"https://maps.gstatic.com/mapfiles/place_api/icons/school-71.png",\n'
#  '            "id": "09918e0ca8e9c88ceb7bcf12d60c9521384b19d3",\n'
#  '            "name": "Biotonic Brickell",\n'
#  '            "opening_hours": {\n'
#  '                "open_now": true\n'
#  '            },\n'
#  '            "place_id": "ChIJX5sqpIS22YgRK5w8XScIUaM",\n'
#  '            "plus_code": {\n'
#  '                "compound_code": "QR85+4V Miami, Florida, United States",\n'
#  '                "global_code": "76QXQR85+4V"\n'
#  '            },\n'
#  '            "reference": "ChIJX5sqpIS22YgRK5w8XScIUaM",\n'
#  '            "scope": "GOOGLE",\n'
#  '            "types": [\n'
#  '                "gym",\n'
#  '                "health",\n'
#  '                "point_of_interest",\n'
#  '                "establishment"\n'
#  '            ],\n'
#  '            "vicinity": "801 Brickell Bay Drive, Miami"\n'
#  '        },\n'
#  '        {\n'
#  '            "geometry": {\n'
#  '                "location": {\n'
#  '                    "lat": 25.7610707,\n'
#  '                    "lng": -80.19434389999999\n'
#  '                },\n'
#  '                "viewport": {\n'
#  '                    "northeast": {\n'
#  '                        "lat": 25.7621877302915,\n'
#  '                        "lng": -80.19298646970849\n'
#  '                    },\n'
#  '                    "southwest": {\n'
#  '                        "lat": 25.7594897697085,\n'
#  '                        "lng": -80.1956844302915\n'
#  '                    }\n'
#  '                }\n'
#  '            },\n'
#  '            "icon": '
#  '"https://maps.gstatic.com/mapfiles/place_api/icons/school-71.png",\n'
#  '            "id": "bc530a74aaf17d1cc78c7224623eabec0ff1b961",\n'
#  '            "name": "Pilates Center by Bernadette",\n'
#  '            "opening_hours": {\n'
#  '                "open_now": true\n'
#  '            },\n'
#  '            "photos": [\n'
#  '                {\n'
#  '                    "height": 1536,\n'
#  '                    "html_attributions": [\n'
#  '                        "<a '
#  'href=\\"https://maps.google.com/maps/contrib/111946048439122721431/photos\\">Laura '
#  'Stodola</a>"\n'
#  '                    ],\n'
#  '                    "photo_reference": '
#  '"CmRaAAAABzRbaBSIqcQvu1-rM24uCPC4cAvjA9hBZE1SxWLCgKMusE1e_8buLuAykl2t8nIpaKZaknPvxvp9rf64nulAfzVHFyq-uW3lKeT-K5pv-gVO9ch6ocP5XVybV2vS6JAIEhDoONUt9JfggcyKhoZvfT8pGhT_T_K1wPZGTsX4vJQ2bAkmYdmM6A",\n'
#  '                    "width": 2048\n'
#  '                }\n'
#  '            ],\n'
#  '            "place_id": "ChIJYax_SYG22YgRXzusxMgn4Mo",\n'
#  '            "plus_code": {\n'
#  '                "compound_code": "QR64+C7 Miami, Florida, United States",\n'
#  '                "global_code": "76QXQR64+C7"\n'
#  '            },\n'
#  '            "rating": 4,\n'
#  '            "reference": "ChIJYax_SYG22YgRXzusxMgn4Mo",\n'
#  '            "scope": "GOOGLE",\n'
#  '            "types": [\n'
#  '                "gym",\n'
#  '                "health",\n'
#  '                "point_of_interest",\n'
#  '                "establishment"\n'
#  '            ],\n'
#  '            "user_ratings_total": 1,\n'
#  '            "vicinity": "260 Crandon Boulevard #36, Key Biscayne"\n'
#  '        },\n'
#  '        {\n'
#  '            "geometry": {\n'
#  '                "location": {\n'
#  '                    "lat": 25.7631266,\n'
#  '                    "lng": -80.1917917\n'
#  '                },\n'
#  '                "viewport": {\n'
#  '                    "northeast": {\n'
#  '                        "lat": 25.7644535802915,\n'
#  '                        "lng": -80.19034046970849\n'
#  '                    },\n'
#  '                    "southwest": {\n'
#  '                        "lat": 25.7617556197085,\n'
#  '                        "lng": -80.1930384302915\n'
#  '                    }\n'
#  '                }\n'
#  '            },\n'
#  '            "icon": '
#  '"https://maps.gstatic.com/mapfiles/place_api/icons/generic_business-71.png",\n'
#  '            "id": "673fe25e455380fe79886545c45740586b449626",\n'
#  '            "name": "The Cage Boxing Club",\n'
#  '            "opening_hours": {\n'
#  '                "open_now": true\n'
#  '            },\n'
#  '            "photos": [\n'
#  '                {\n'
#  '                    "height": 1959,\n'
#  '                    "html_attributions": [\n'
#  '                        "<a '
#  'href=\\"https://maps.google.com/maps/contrib/115582989413202018865/photos\\">The '
#  'Cage Boxing Club</a>"\n'
#  '                    ],\n'
#  '                    "photo_reference": '
#  '"CmRaAAAAoHsX6pkoNrE9QWuzWmIIY_hrDVO4DWuzk3fDHJNpd821bCP2QoDECrx0rhVkNR0FRaWXqm50RcfWB_Eeyf0EBgnZxs4cagRfhrqgaTzvvu5lzbywspL49_zNgjYGrPY_EhAKjkAM-IicuDzQM4zJJgVcGhQBpxCQzQc2LXsZrEAqEJ226yOGXA",\n'
#  '                    "width": 2048\n'
#  '                }\n'
#  '            ],\n'
#  '            "place_id": "ChIJq19j5IO22YgRoA0iymGhYh4",\n'
#  '            "plus_code": {\n'
#  '                "compound_code": "QR75+77 Miami, Florida, United States",\n'
#  '                "global_code": "76QXQR75+77"\n'
#  '            },\n'
#  '            "rating": 3.4,\n'
#  '            "reference": "ChIJq19j5IO22YgRoA0iymGhYh4",\n'
#  '            "scope": "GOOGLE",\n'
#  '            "types": [\n'
#  '                "gym",\n'
#  '                "health",\n'
#  '                "point_of_interest",\n'
#  '                "establishment"\n'
#  '            ],\n'
#  '            "user_ratings_total": 33,\n'
#  '            "vicinity": "1060 Brickell Avenue #M3, Miami"\n'
#  '        },\n'
#  '        {\n'
#  '            "geometry": {\n'
#  '                "location": {\n'
#  '                    "lat": 25.7712666,\n'
#  '                    "lng": -80.1893937\n'
#  '                },\n'
#  '                "viewport": {\n'
#  '                    "northeast": {\n'
#  '                        "lat": 25.7724475802915,\n'
#  '                        "lng": -80.1880431697085\n'
#  '                    },\n'
#  '                    "southwest": {\n'
#  '                        "lat": 25.7697496197085,\n'
#  '                        "lng": -80.1907411302915\n'
#  '                    }\n'
#  '                }\n'
#  '            },\n'
#  '            "icon": '
#  '"https://maps.gstatic.com/mapfiles/place_api/icons/school-71.png",\n'
#  '            "id": "dfbfa2a87612cf9430b9967f3ed17856758544a6",\n'
#  '            "name": "Yoga with Anamaria",\n'
#  '            "opening_hours": {\n'
#  '                "open_now": true\n'
#  '            },\n'
#  '            "photos": [\n'
#  '                {\n'
#  '                    "height": 3120,\n'
#  '                    "html_attributions": [\n'
#  '                        "<a '
#  'href=\\"https://maps.google.com/maps/contrib/112560017899840831296/photos\\">Anamaria</a>"\n'
#  '                    ],\n'
#  '                    "photo_reference": '
#  '"CmRaAAAA-Ow94f98V6chMIFqAwCb9TxLbT-gm-LlOoOt2lLhCjeCe0LmeVOXdXFBTkmTxgCwh1auZASENz4nviHtgAbMkFZLlxIV_-kyh_t-Jz2l3nvtilKARK0-YY5OT85DziYJEhDkTxyA5-EOIhbwhGfJq_qpGhT1XAoBxDfpQfq5vszSDxHEJuSdWw",\n'
#  '                    "width": 4160\n'
#  '                }\n'
#  '            ],\n'
#  '            "place_id": "ChIJg-feC-y22YgR25pIxL-Xah8",\n'
#  '            "plus_code": {\n'
#  '                "compound_code": "QRC6+G6 Miami, Florida, United States",\n'
#  '                "global_code": "76QXQRC6+G6"\n'
#  '            },\n'
#  '            "rating": 5,\n'
#  '            "reference": "ChIJg-feC-y22YgR25pIxL-Xah8",\n'
#  '            "scope": "GOOGLE",\n'
#  '            "types": [\n'
#  '                "gym",\n'
#  '                "health",\n'
#  '                "point_of_interest",\n'
#  '                "school",\n'
#  '                "establishment"\n'
#  '            ],\n'
#  '            "user_ratings_total": 5,\n'
#  '            "vicinity": "255 Biscayne Boulevard Way, Miami"\n'
#  '        },\n'
#  '        {\n'
#  '            "geometry": {\n'
#  '                "location": {\n'
#  '                    "lat": 25.77219819999999,\n'
#  '                    "lng": -80.1881477\n'
#  '                },\n'
#  '                "viewport": {\n'
#  '                    "northeast": {\n'
#  '                        "lat": 25.7733537302915,\n'
#  '                        "lng": -80.1867892697085\n'
#  '                    },\n'
#  '                    "southwest": {\n'
#  '                        "lat": 25.77065576970849,\n'
#  '                        "lng": -80.1894872302915\n'
#  '                    }\n'
#  '                }\n'
#  '            },\n'
#  '            "icon": '
#  '"https://maps.gstatic.com/mapfiles/place_api/icons/generic_business-71.png",\n'
#  '            "id": "0c33e1047e4775fac52b0a5fc52e4526e4e49ade",\n'
#  '            "name": "Athleatz",\n'
#  '            "opening_hours": {\n'
#  '                "open_now": true\n'
#  '            },\n'
#  '            "photos": [\n'
#  '                {\n'
#  '                    "height": 444,\n'
#  '                    "html_attributions": [\n'
#  '                        "<a '
#  'href=\\"https://maps.google.com/maps/contrib/103442611752473907278/photos\\">Athleatz</a>"\n'
#  '                    ],\n'
#  '                    "photo_reference": '
#  '"CmRaAAAAckB0HlWMRFNx0Nl0ygr7SpAsACnNkMNwUtR03to1FsadyYje1bBR2D-WB8T_fvyE3aEf8zVF3S85fpoBrjkY71JrtcsXiVNpi5ZRpY_aQZD-RIHLNVkWpfdQpFjMuuOrEhAi-NMAiSLwLLpHb_DenmfeGhTGvOrRM5xnq1ZRp5ikvTB5Ll19eA",\n'
#  '                    "width": 1097\n'
#  '                }\n'
#  '            ],\n'
#  '            "place_id": "ChIJgwRBiZ222YgR_CgLVrU5duU",\n'
#  '            "plus_code": {\n'
#  '                "compound_code": "QRC6+VP Miami, Florida, United States",\n'
#  '                "global_code": "76QXQRC6+VP"\n'
#  '            },\n'
#  '            "reference": "ChIJgwRBiZ222YgR_CgLVrU5duU",\n'
#  '            "scope": "GOOGLE",\n'
#  '            "types": [\n'
#  '                "gym",\n'
#  '                "store",\n'
#  '                "health",\n'
#  '                "point_of_interest",\n'
#  '                "establishment"\n'
#  '            ],\n'
#  '            "vicinity": "Southeast Financial Center, 200 South Biscayne '
#  'Boulevard #2791, Miami"\n'
#  '        },\n'
#  '        {\n'
#  '            "geometry": {\n'
#  '                "location": {\n'
#  '                    "lat": 25.7655526,\n'
#  '                    "lng": -80.1938053\n'
#  '                },\n'
#  '                "viewport": {\n'
#  '                    "northeast": {\n'
#  '                        "lat": 25.7668417302915,\n'
#  '                        "lng": -80.1924539197085\n'
#  '                    },\n'
#  '                    "southwest": {\n'
#  '                        "lat": 25.7641437697085,\n'
#  '                        "lng": -80.1951518802915\n'
#  '                    }\n'
#  '                }\n'
#  '            },\n'
#  '            "icon": '
#  '"https://maps.gstatic.com/mapfiles/place_api/icons/generic_business-71.png",\n'
#  '            "id": "b5d0de53044c620b026a55ac5f3d293b76028909",\n'
#  '            "name": "Equinox Brickell Heights",\n'
#  '            "opening_hours": {\n'
#  '                "open_now": true\n'
#  '            },\n'
#  '            "photos": [\n'
#  '                {\n'
#  '                    "height": 3036,\n'
#  '                    "html_attributions": [\n'
#  '                        "<a '
#  'href=\\"https://maps.google.com/maps/contrib/103485627635972293253/photos\\">Michael '
#  'Armentano</a>"\n'
#  '                    ],\n'
#  '                    "photo_reference": '
#  '"CmRaAAAAnvJvtyKK1x6P-A3w519b64lOYNzXt8dOeUpYXPH68tk5ih6hKTvz1U6Ed6cK_eTg6_hXg4e3D2G2ZQjA0W9xTZBFdcooDNpnugqZmbocwO5qcokC5f5AAYZAFW7cHORrEhDCU2lrAc15fvV4aakWCPswGhTm3NwVsvBDAQ_P9VO1V6XcdSSY6g",\n'
#  '                    "width": 4048\n'
#  '                }\n'
#  '            ],\n'
#  '            "place_id": "ChIJSUPxcYO22YgRkmTfVewsV6M",\n'
#  '            "plus_code": {\n'
#  '                "compound_code": "QR84+6F Miami, Florida, United States",\n'
#  '                "global_code": "76QXQR84+6F"\n'
#  '            },\n'
#  '            "rating": 3.5,\n'
#  '            "reference": "ChIJSUPxcYO22YgRkmTfVewsV6M",\n'
#  '            "scope": "GOOGLE",\n'
#  '            "types": [\n'
#  '                "gym",\n'
#  '                "spa",\n'
#  '                "health",\n'
#  '                "point_of_interest",\n'
#  '                "establishment"\n'
#  '            ],\n'
#  '            "user_ratings_total": 36,\n'
#  '            "vicinity": "25 Southwest 9th Street g103, Miami"\n'
#  '        },\n'
#  '        {\n'
#  '            "geometry": {\n'
#  '                "location": {\n'
#  '                    "lat": 25.7678936,\n'
#  '                    "lng": -80.19349079999999\n'
#  '                },\n'
#  '                "viewport": {\n'
#  '                    "northeast": {\n'
#  '                        "lat": 25.7692598302915,\n'
#  '                        "lng": -80.19208241970848\n'
#  '                    },\n'
#  '                    "southwest": {\n'
#  '                        "lat": 25.76656186970849,\n'
#  '                        "lng": -80.1947803802915\n'
#  '                    }\n'
#  '                }\n'
#  '            },\n'
#  '            "icon": '
#  '"https://maps.gstatic.com/mapfiles/place_api/icons/generic_business-71.png",\n'
#  '            "id": "2ca83ffee1ed3edb2a8c71128762660b5c4854cc",\n'
#  '            "name": "EPIC Hybrid Training - Miami",\n'
#  '            "opening_hours": {\n'
#  '                "open_now": true\n'
#  '            },\n'
#  '            "photos": [\n'
#  '                {\n'
#  '                    "height": 4016,\n'
#  '                    "html_attributions": [\n'
#  '                        "<a '
#  'href=\\"https://maps.google.com/maps/contrib/112459749723373303559/photos\\">EPIC '
#  'Hybrid Training - Miami</a>"\n'
#  '                    ],\n'
#  '                    "photo_reference": '
#  '"CmRaAAAAxYNdE8xa8XN3JwmtU9eWW1bMX_lhD-T1OMd6kCB6xD5E03AP3iYOes45nGGC5QF-nhat9VAzFFITPff-MAeewsCrDa5tkS00gqDYDBo6Q95fApUCqlBNOG4AGwh1o2iMEhCrh4jctKSV-sMV8zpUz79fGhQpoCXnEh4e5bSQvFi93mgZhmCICQ",\n'
#  '                    "width": 6016\n'
#  '                }\n'
#  '            ],\n'
#  '            "place_id": "ChIJk0rxpYS22YgRa73jWpuCedk",\n'
#  '            "plus_code": {\n'
#  '                "compound_code": "QR94+5J Miami, Florida, United States",\n'
#  '                "global_code": "76QXQR94+5J"\n'
#  '            },\n'
#  '            "rating": 4.3,\n'
#  '            "reference": "ChIJk0rxpYS22YgRa73jWpuCedk",\n'
#  '            "scope": "GOOGLE",\n'
#  '            "types": [\n'
#  '                "gym",\n'
#  '                "health",\n'
#  '                "point_of_interest",\n'
#  '                "establishment"\n'
#  '            ],\n'
#  '            "user_ratings_total": 12,\n'
#  '            "vicinity": "620 South Miami Avenue, Miami"\n'
#  '        },\n'
#  '        {\n'
#  '            "geometry": {\n'
#  '                "location": {\n'
#  '                    "lat": 25.7655381,\n'
#  '                    "lng": -80.1940393\n'
#  '                },\n'
#  '                "viewport": {\n'
#  '                    "northeast": {\n'
#  '                        "lat": 25.7668307302915,\n'
#  '                        "lng": -80.1926880697085\n'
#  '                    },\n'
#  '                    "southwest": {\n'
#  '                        "lat": 25.7641327697085,\n'
#  '                        "lng": -80.1953860302915\n'
#  '                    }\n'
#  '                }\n'
#  '            },\n'
#  '            "icon": '
#  '"https://maps.gstatic.com/mapfiles/place_api/icons/generic_business-71.png",\n'
#  '            "id": "c072391d0c8891043383f943c2b26c193a8f973b",\n'
#  '            "name": "SoulCycle BRKL - Brickell",\n'
#  '            "opening_hours": {\n'
#  '                "open_now": true\n'
#  '            },\n'
#  '            "photos": [\n'
#  '                {\n'
#  '                    "height": 2988,\n'
#  '                    "html_attributions": [\n'
#  '                        "<a '
#  'href=\\"https://maps.google.com/maps/contrib/116016461676575222719/photos\\">roy '
#  'lehto</a>"\n'
#  '                    ],\n'
#  '                    "photo_reference": '
#  '"CmRaAAAAw5KpZ6xX1tBt7cBmdJZXNnCA1UEQ-mw0SFGdWNAd9HfBtEBgLljZGRxNXuxoQ_U1Fm3chcaAObxnWjW9zF5_xrzd2GNBR07CQ0LJawxQPwU8zZ1FA-1BegtXhLJsqvRzEhDo1u32aq56qhoCx69pmAn_GhR0m5VEcVhF1b24FGqZSDyDyYslMw",\n'
#  '                    "width": 5312\n'
#  '                }\n'
#  '            ],\n'
#  '            "place_id": "ChIJ-4hGe4S22YgR6yH_yyouVXA",\n'
#  '            "plus_code": {\n'
#  '                "compound_code": "QR84+69 Miami, Florida, United States",\n'
#  '                "global_code": "76QXQR84+69"\n'
#  '            },\n'
#  '            "rating": 5,\n'
#  '            "reference": "ChIJ-4hGe4S22YgR6yH_yyouVXA",\n'
#  '            "scope": "GOOGLE",\n'
#  '            "types": [\n'
#  '                "gym",\n'
#  '                "health",\n'
#  '                "point_of_interest",\n'
#  '                "establishment"\n'
#  '            ],\n'
#  '            "user_ratings_total": 18,\n'
#  '            "vicinity": "25 Southwest 9th Street g102, Miami"\n'
#  '        },\n'
#  '        {\n'
#  '            "geometry": {\n'
#  '                "location": {\n'
#  '                    "lat": 25.7664573,\n'
#  '                    "lng": -80.19474129999999\n'
#  '                },\n'
#  '                "viewport": {\n'
#  '                    "northeast": {\n'
#  '                        "lat": 25.7677648802915,\n'
#  '                        "lng": -80.19339156970848\n'
#  '                    },\n'
#  '                    "southwest": {\n'
#  '                        "lat": 25.7650669197085,\n'
#  '                        "lng": -80.1960895302915\n'
#  '                    }\n'
#  '                }\n'
#  '            },\n'
#  '            "icon": '
#  '"https://maps.gstatic.com/mapfiles/place_api/icons/generic_business-71.png",\n'
#  '            "id": "37297f6fe7053e741706e624137cbfe788fbbbfc",\n'
#  '            "name": "Trainer Shawn Personal Fitness Miami Brickell",\n'
#  '            "opening_hours": {\n'
#  '                "open_now": true\n'
#  '            },\n'
#  '            "photos": [\n'
#  '                {\n'
#  '                    "height": 500,\n'
#  '                    "html_attributions": [\n'
#  '                        "<a '
#  'href=\\"https://maps.google.com/maps/contrib/107784595474812669175/photos\\">Trainer '
#  'Shawn Personal Fitness Miami Brickell</a>"\n'
#  '                    ],\n'
#  '                    "photo_reference": '
#  '"CmRaAAAA8zE_lqVrXNvkkTNvfMF-fo7iLsxUt3oS84BpclIkEzXKkYLGpez_Hsdv8WPz-KuRsJ8epA8N7apWlmi9WhHFuCRFFa0-YM3swDXShaeifr8lcP_f03XOucpuZxP-aAXEEhBGOPAyDNFHYuKc7g3lgy1LGhQDAw7g4bwFg-62fluykDdDgBYeDQ",\n'
#  '                    "width": 500\n'
#  '                }\n'
#  '            ],\n'
#  '            "place_id": "ChIJ53j9u5G22YgRlQsPKR6feRI",\n'
#  '            "plus_code": {\n'
#  '                "compound_code": "QR84+H4 Miami, Florida, United States",\n'
#  '                "global_code": "76QXQR84+H4"\n'
#  '            },\n'
#  '            "rating": 5,\n'
#  '            "reference": "ChIJ53j9u5G22YgRlQsPKR6feRI",\n'
#  '            "scope": "GOOGLE",\n'
#  '            "types": [\n'
#  '                "gym",\n'
#  '                "health",\n'
#  '                "point_of_interest",\n'
#  '                "establishment"\n'
#  '            ],\n'
#  '            "user_ratings_total": 9,\n'
#  '            "vicinity": "479 Southwest 3rd Street, Miami"\n'
#  '        }\n'
#  '    ],\n'
#  '    "status": "OK"\n'
#  '}')

# %%
namegymzip = []
addressgymzip = []
userratingszip = []
pagetoken = gym_zip["next_page_token"]

for place in gym_zip["results"]:
    try:
        namegymzip.append(place["name"])
        addressgymzip.append(place["vicinity"])
        userratingszip.append(place["user_ratings_total"])
    except:
        userratingszip.append("na")
print(pagetoken)
# Out:
# CqQCGQEAAKjXdcrH1leAjlw6T8R2y15lHW8Kan-_xOQXeCvKO2pShMpxNVbAAZpQ1CHK4AJEIxOnMFKChbMfWqVh1ocgIIeWmwjgvsx6iAXqK0P4haOuPYX2Q8JcW80I15LhXrg1_D4ZSTD-GzFe_Uu9r30h3AckSHZaeIgMo1R9V8SZNftlR83j-r_gPdvrxUMNozlwmJM_ly4vQeoIQrbkitMhsnmf_N92UT3eelhMlKy2yIwVAs_sPpO67wQpXAcGH4qMq6GVhOHEbVNfrLbytUkuxHjART5quyEcnSO2gagzEv4cYBkQLdQJI08u60GCxpU6NMqrqj78Zd-zxr6q4AfQRRKjT6g_FKEOsqiO7bkw6Z_YLEvO73wWffsxgEyCPoseWxIQv0_ULRFJNOVfeth25ck8kxoULkohqhxrhqsJfAHAB0mzuUsj93E

# %%
# create a dictionary and then a data frame
gymlist_dict = {
    "ZIP": zip_coords,
    "Gym": namegymzip,
    "Address": addressgymzip,
    "User Ratings": userratingszip
}
gymlist_data = pd.DataFrame(gymlist_dict)
gymlist_data
# Out:
#                      ZIP                                            Gym  \
# 0   25.76528,-80.1847167                          Exhale Downtown Miami
# 1   25.76528,-80.1847167                                     LA Fitness
# 2   25.76528,-80.1847167                 Hot Yoga Brickell (Nacho Cano)
# 3   25.76528,-80.1847167                        Sanctuary Seven Pilates
# 4   25.76528,-80.1847167                               Equinox Brickell
# 5   25.76528,-80.1847167                             Skanda Yoga Studio
# 6   25.76528,-80.1847167                                   Cure Fitness
# 7   25.76528,-80.1847167                       Dubail Fitness Institute
# 8   25.76528,-80.1847167                                    Dharmi Yoga
# 9   25.76528,-80.1847167                              Getting Fit Miami
# 10  25.76528,-80.1847167                           Orangetheory Fitness
# 11  25.76528,-80.1847167                              Biotonic Brickell
# 12  25.76528,-80.1847167                   Pilates Center by Bernadette
# 13  25.76528,-80.1847167                           The Cage Boxing Club
# 14  25.76528,-80.1847167                             Yoga with Anamaria
# 15  25.76528,-80.1847167                                       Athleatz
# 16  25.76528,-80.1847167                       Equinox Brickell Heights
# 17  25.76528,-80.1847167                   EPIC Hybrid Training - Miami
# 18  25.76528,-80.1847167                      SoulCycle BRKL - Brickell
# 19  25.76528,-80.1847167  Trainer Shawn Personal Fitness Miami Brickell
#
#                                               Address User Ratings
# 0               270 Biscayne Boulevard Way #16, Miami           21
# 1                  900 South Miami Avenue #236, Miami          239
# 2                     809 Southwest 1st Avenue, Miami           28
# 3                    1797 Southwest 3rd Avenue, Miami           13
# 4                      1441 Brickell Avenue #4, Miami           41
# 5               1800 Southwest 1st Avenue #102, Miami           32
# 6                    1800 Southwest 1st Avenue, Miami            7
# 7                    1785 Southwest 3rd Avenue, Miami           13
# 8              118 Southwest South River Drive, Miami            1
# 9                      199 East Flagler Street, Miami           na
# 10                      244 Biscayne Boulevard, Miami           54
# 11                      801 Brickell Bay Drive, Miami           na
# 12            260 Crandon Boulevard #36, Key Biscayne            1
# 13                    1060 Brickell Avenue #M3, Miami           33
# 14                  255 Biscayne Boulevard Way, Miami            5
# 15  Southeast Financial Center, 200 South Biscayne...           na
# 16                25 Southwest 9th Street g103, Miami           36
# 17                      620 South Miami Avenue, Miami           12
# 18                25 Southwest 9th Street g102, Miami           18
# 19                    479 Southwest 3rd Street, Miami            9

# %%
# 3. Find the name and address of a gym in the zips. Needs to be gym as it is the type name provided by google
#    Hint: See https://developers.google.com/places/web-service/supported_types

for zips in zipcode_data["zip"][:5]: 
    target_type = "gym"
    zip_coords = ["latit"],["longi"]
    radius = 2000

# rewrite params dict

    params3 = {
    "location": zip_coords,
    "types": target_type,
    "radius": radius,
    "key": gkey
    "pagetoken": pagetoken
}

# Build URL using the Google Maps API
    base_url3 = "https://maps.googleapis.com/maps/api/place/nearbysearch/json"

    print("Fitness Center near ZIP")

# Run request
    response = requests.get(base_url3, params3)
    gym_zips = response.json()
    
# Print the JSON (pretty printed)
    pprint(json.dumps(gym_zips, indent=4, sort_keys=True))
# Out:
#   File "<ipython-input-117-51cf0b566200>", line 16
#     "pagetoken": pagetoken
#               ^
# SyntaxError: invalid syntax
